# %% [markdown]
# ## Installing the correct verisons.

# %%
# 1. Define the exact environment specifications
requirements_content = """
absl-py==2.3.1
appnope==0.1.4
asttokens==3.0.1
astunparse==1.6.3
certifi==2026.1.4
charset-normalizer==3.4.4
comm==0.2.3
contourpy==1.3.0
cycler==0.12.1
debugpy==1.8.20
decorator==5.2.1
exceptiongroup==1.3.1
executing==2.2.1
filelock==3.19.1
flatbuffers==25.12.19
fonttools==4.60.2
fsspec==2025.10.0
gast==0.7.0
google-pasta==0.2.0
grpcio==1.78.0
h5py==3.14.0
idna==3.11
importlib_metadata==8.7.1
importlib_resources==6.5.2
ipykernel==6.31.0
ipython==8.18.1
jedi==0.19.2
Jinja2==3.1.6
joblib==1.5.3
jupyter_client==8.6.3
jupyter_core==5.8.1
keras==3.10.0
kiwisolver==1.4.7
libclang==18.1.1
Markdown==3.9
markdown-it-py==3.0.0
MarkupSafe==3.0.3
matplotlib==3.9.4
matplotlib-inline==0.2.1
mdurl==0.1.2
ml_dtypes==0.5.4
mpmath==1.3.0
namex==0.1.0
nest-asyncio==1.6.0
networkx==3.2.1
numpy==2.0.2
opt_einsum==3.4.0
optree==0.18.0
packaging==26.0
pandas==2.3.3
parso==0.8.6
pexpect==4.9.0
pillow==11.3.0
platformdirs==4.4.0
prompt_toolkit==3.0.52
protobuf==6.33.5
psutil==7.2.2
ptyprocess==0.7.0
pure_eval==0.2.3
Pygments==2.19.2
pyparsing==3.3.2
python-dateutil==2.9.0.post0
pytz==2025.2
pyzmq==27.1.0
requests==2.32.5
rich==14.3.2
scikit-learn==1.6.1
scipy==1.13.1
six==1.17.0
sklearn==0.0
stack-data==0.6.3
sympy==1.14.0
tensorboard==2.20.0
tensorboard-data-server==0.7.2
tensorflow==2.20.0
termcolor==3.1.0
threadpoolctl==3.6.0
torch==2.8.0
tornado==6.5.4
traitlets==5.14.3
typing_extensions==4.15.0
tzdata==2025.3
urllib3==2.6.3
wcwidth==0.6.0
Werkzeug==3.1.5
wrapt==2.1.1
zipp==3.23.0
"""

# 2. Write this content to requirements.txt (Overwriting if it exists)
with open("requirements.txt", "w") as f:
    f.write(requirements_content.strip())

print("✅ requirements.txt has been updated with your environment versions.")

# 3. Force install these specific versions into the current Jupyter environment
print("⏳ Installing packages... this may take a moment...")
# %pip install -r requirements.txt
print("✅ Installation complete. Environment is synchronized.")
# Out:
# ✅ requirements.txt has been updated with your environment versions.
# ⏳ Installing packages... this may take a moment...
# ...
# Note: you may need to restart the kernel to use updated packages.
# ✅ Installation complete. Environment is synchronized.
